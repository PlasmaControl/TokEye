# %% [markdown]
# # step_8 — eval
#
# Score the exported model on the tj-ii benchmark.
#
# Read-only. Submitting is `sbatch step_8_eval.sh` in the shell;
# knobs are in `step_8_eval.yml`.

# %%
from tokeye.training.big_tf_unet_2 import view

v = view.here()
v.status()

# %%
v.gallery('step_8')

# %%
v.log('step_8')

# %% [markdown]
# Auto-resolved values this step picked, and where its knobs live:

# %%
v.suggest('step_8')

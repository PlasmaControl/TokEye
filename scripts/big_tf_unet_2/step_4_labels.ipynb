# %% [markdown]
# # step_4 — labels
#
# Threshold the residual into coherent/transient masks.
#
# Read-only. Submitting is `sbatch step_4_labels.sh` in the shell;
# knobs are in `step_4_labels.yml`.

# %%
from tokeye.training.big_tf_unet_2 import view

v = view.here()
v.status()

# %%
v.gallery('step_4')

# %%
v.log('step_4')

# %% [markdown]
# Auto-resolved values this step picked, and where its knobs live:

# %%
v.suggest('step_4')

# %% [markdown]
# # step_6 — refine
#
# 5-fold out-of-fold predictions — a leakage-free second opinion.
#
# Read-only. Submitting is `sbatch step_6_refine.sh` in the shell;
# knobs are in `step_6_refine.yml`.

# %%
from tokeye.training.big_tf_unet_2 import view

v = view.here()
v.status()

# %%
v.gallery('step_6')

# %%
v.log('step_6')

# %% [markdown]
# Auto-resolved values this step picked, and where its knobs live:

# %%
v.suggest('step_6')

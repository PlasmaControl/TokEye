# %% [markdown]
# # step_0 — intake
#
# Load raw shot data, resample, pre-emphasize, cut into windows.
#
# Read-only. Submitting is `sbatch step_0_intake.sh` in the shell;
# knobs are in `step_0_intake.yml`.

# %%
from tokeye.training.big_tf_unet_2 import view

v = view.here()
v.status()

# %%
v.gallery('step_0')

# %%
v.log('step_0')

# %% [markdown]
# Auto-resolved values this step picked, and where its knobs live:

# %%
v.suggest('step_0')

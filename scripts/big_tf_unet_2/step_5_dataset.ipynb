# %% [markdown]
# # step_5 — dataset
#
# Pack every modality into one training set.
#
# Read-only. Submitting is `sbatch step_5_dataset.sh` in the shell;
# knobs are in `step_5_dataset.yml`.

# %%
from tokeye.training.big_tf_unet_2 import view

v = view.here()
v.status()

# %%
v.gallery('step_5')

# %%
v.log('step_5')

# %% [markdown]
# Auto-resolved values this step picked, and where its knobs live:

# %%
v.suggest('step_5')

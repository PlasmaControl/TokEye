# %% [markdown]
# # step_2 — baseline
#
# Remove the smooth background (baseline) from each spectrogram.
#
# Read-only. Submitting is `sbatch step_2_baseline.sh` in the shell;
# knobs are in `step_2_baseline.yml`.

# %%
from tokeye.training.big_tf_unet_2 import view

v = view.here()
v.status()

# %%
v.gallery('step_2')

# %%
v.log('step_2')

# %% [markdown]
# Auto-resolved values this step picked, and where its knobs live:

# %%
v.suggest('step_2')

# %% [markdown]
# # step_3 — denoise
#
# Self-supervised cross-channel denoiser, one model per modality.
#
# Read-only. Submitting is `sbatch step_3_denoise.sh` in the shell;
# knobs are in `step_3_denoise.yml`.

# %%
from tokeye.training.big_tf_unet_2 import view

v = view.here()
v.status()

# %%
v.gallery('step_3')

# %%
v.log('step_3')

# %% [markdown]
# Auto-resolved values this step picked, and where its knobs live:

# %%
v.suggest('step_3')
